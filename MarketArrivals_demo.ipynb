# %%
from sklearn import datasets
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import accuracy_score

from sklearn.model_selection import train_test_split
# prophet
from fbprophet import Prophet
from fbprophet.plot import plot_plotly, plot_components_plotly, plot_cross_validation_metric
from fbprophet.diagnostics import cross_validation, performance_metrics

import joblib

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import datetime as DT

# %%
# dataset source: https://github.com/rouseguy
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/MarketArrivals.csv')
df['ds'] = df.date.apply(lambda x: DT.datetime.strptime(x, '%B-%Y').date())
df.rename(columns={'quantity':'y'}, inplace=True)
#df['month_num'] = df.datetime.apply(lambda x: x.month)
df
# Out:
#            market     month  year       y  priceMin  priceMax  priceMod state  \
# 0      ABOHAR(PB)   January  2005    2350       404       493       446    PB
# 1      ABOHAR(PB)   January  2006     900       487       638       563    PB
# 2      ABOHAR(PB)   January  2010     790      1283      1592      1460    PB
# 3      ABOHAR(PB)   January  2011     245      3067      3750      3433    PB
# 4      ABOHAR(PB)   January  2012    1035       523       686       605    PB
# ...           ...       ...   ...     ...       ...       ...       ...   ...
# 10222   YEOLA(MS)  December  2011  131326       282       612       526    MS
# 10223   YEOLA(MS)  December  2012  207066       485      1327      1136    MS
# 10224   YEOLA(MS)  December  2013  215883       472      1427      1177    MS
# 10225   YEOLA(MS)  December  2014  201077       446      1654      1456    MS
# 10226   YEOLA(MS)  December  2015  223315       609      1446      1126    MS
#
#          city           date          ds
# 0      ABOHAR   January-2005  2005-01-01
# 1      ABOHAR   January-2006  2006-01-01
# 2      ABOHAR   January-2010  2010-01-01
# 3      ABOHAR   January-2011  2011-01-01
# 4      ABOHAR   January-2012  2012-01-01
# ...       ...            ...         ...
# 10222   YEOLA  December-2011  2011-12-01
# 10223   YEOLA  December-2012  2012-12-01
# 10224   YEOLA  December-2013  2013-12-01
# 10225   YEOLA  December-2014  2014-12-01
# 10226   YEOLA  December-2015  2015-12-01
#
# [10227 rows x 11 columns]

# %%
df = df.drop(['market', 'month', 'state', 'date', 'year'], axis = 1)
df = df.loc[df.city=='YEOLA', :]
df
# Out:
#             y  priceMin  priceMax  priceMod   city          ds
# 10081   56549       376       795       741  YEOLA  2004-01-01
# 10082  202348       149       261       231  YEOLA  2005-01-01
# 10083  184865       135       299       268  YEOLA  2006-01-01
# 10084  164865       431       977       870  YEOLA  2007-01-01
# 10085  387738       150       272       214  YEOLA  2008-01-01
# ...       ...       ...       ...       ...    ...         ...
# 10222  131326       282       612       526  YEOLA  2011-12-01
# 10223  207066       485      1327      1136  YEOLA  2012-12-01
# 10224  215883       472      1427      1177  YEOLA  2013-12-01
# 10225  201077       446      1654      1456  YEOLA  2014-12-01
# 10226  223315       609      1446      1126  YEOLA  2015-12-01
#
# [146 rows x 6 columns]

# %%
df.shape
# Out:
# (146, 6)

# %%
def train_test_split(timeseries, test_size=12):
    return timeseries[:-test_size], timeseries[-test_size:]

# %%
city_to_filter = 'YEOLA'

# %%
df_city = df[df.city == city_to_filter]
train, test = train_test_split(df)

# %%
test
# Out:
#             y  priceMin  priceMax  priceMod   city          ds
# 10215   83888       149       320       276  YEOLA  2004-12-01
# 10216  105734       223       474       432  YEOLA  2005-12-01
# 10217  123824       273       656       577  YEOLA  2006-12-01
# 10218  232281       250       478       388  YEOLA  2007-12-01
# 10219  128291       503      1070       969  YEOLA  2008-12-01
# 10220  112061       479      1536      1018  YEOLA  2009-12-01
# 10221   57586       541      2713      1830  YEOLA  2010-12-01
# 10222  131326       282       612       526  YEOLA  2011-12-01
# 10223  207066       485      1327      1136  YEOLA  2012-12-01
# 10224  215883       472      1427      1177  YEOLA  2013-12-01
# 10225  201077       446      1654      1456  YEOLA  2014-12-01
# 10226  223315       609      1446      1126  YEOLA  2015-12-01

# %%
model = Prophet(interval_width=0.95,
                #     mcmc_samples=300,
).fit(train)

future = model.make_future_dataframe(periods=12, freq='W-MON')

forecast = model.predict(future)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
fig = plot_plotly(model, forecast, trend=True, changepoints=True, xlabel='date', ylabel='quantities', figsize=(1200,800))

# custom styles
fig.update_traces(mode='markers+lines', selector=dict(name='Actual'))

fig.show()
# Out:
# <div>                            <div id="69bcc2bb-41a0-4ed9-951c-08e1c1cb9a60" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("69bcc2bb-41a0-4ed9-951c-08e1c1cb9a60")) {                    Plotly.newPlot(                        "69bcc2bb-41a0-4ed9-951c-08e1c1cb9a60",                        [{"marker": {"color": "black", "size": 4}, "mode": "markers+lines", "name": "Actual", "type": "scatter", "x": ["2004-01-01T00:00:00", "2004-02-01T00:00:00", "2004-03-01T00:00:00", "2004-04-01T00:00:00", "2004-05-01T00:00:00", "2004-06-01T00:00:00", "2004-07-01T00:00:00", "2004-08-01T00:00:00", "2004-09-01T00:00:00", "2004-10-01T00:00:00", "2004-11-01T00:00:00", "2005-01-01T00:00:00", "2005-02-01T00:00:00", "2005-03-01T00:00:00", "2005-04-01T00:00:00", "2005-05-01T00:00:00", "2005-06-01T00:00:00", "2005-07-01T00:00:00", "2005-08-01T00:00:00", "2005-09-01T00:00:00", "2005-10-01T00:00:00", "2005-11-01T00:00:00", "2006-01-01T00:00:00", "2006-02-01T00:00:00", "2006-03-01T00:00:00", "2006-04-01T00:00:00", "2006-05-01T00:00:00", "2006-06-01T00:00:00", "2006-07-01T00:00:00", "2006-08-01T00:00:00", "2006-09-01T00:00:00", "2006-10-01T00:00:00", "2006-11-01T00:00:00", "2007-01-01T00:00:00", "2007-02-01T00:00:00", "2007-03-01T00:00:00", "2007-04-01T00:00:00", "2007-05-01T00:00:00", "2007-06-01T00:00:00", "2007-07-01T00:00:00", "2007-08-01T00:00:00", "2007-09-01T00:00:00", "2007-10-01T00:00:00", "2007-11-01T00:00:00", "2008-01-01T00:00:00", "2008-02-01T00:00:00", "2008-03-01T00:00:00", "2008-04-01T00:00:00", "2008-05-01T00:00:00", "2008-06-01T00:00:00", "2008-07-01T00:00:00", "2008-08-01T00:00:00", "2008-09-01T00:00:00", "2008-10-01T00:00:00", "2008-11-01T00:00:00", "2009-01-01T00:00:00", "2009-02-01T00:00:00", "2009-03-01T00:00:00", "2009-04-01T00:00:00", "2009-05-01T00:00:00", "2009-06-01T00:00:00", "2009-07-01T00:00:00", "2009-08-01T00:00:00", "2009-09-01T00:00:00", "2009-10-01T00:00:00", "2009-11-01T00:00:00", "2010-01-01T00:00:00", "2010-02-01T00:00:00", "2010-03-01T00:00:00", "2010-04-01T00:00:00", "2010-05-01T00:00:00", "2010-06-01T00:00:00", "2010-07-01T00:00:00", "2010-08-01T00:00:00", "2010-09-01T00:00:00", "2010-10-01T00:00:00", "2010-11-01T00:00:00", "2011-01-01T00:00:00", "2011-02-01T00:00:00", "2011-03-01T00:00:00", "2011-04-01T00:00:00", "2011-05-01T00:00:00", "2011-06-01T00:00:00", "2011-07-01T00:00:00", "2011-08-01T00:00:00", "2011-09-01T00:00:00", "2011-10-01T00:00:00", "2011-11-01T00:00:00", "2012-01-01T00:00:00", "2012-02-01T00:00:00", "2012-03-01T00:00:00", "2012-04-01T00:00:00", "2012-05-01T00:00:00", "2012-06-01T00:00:00", "2012-07-01T00:00:00", "2012-08-01T00:00:00", "2012-09-01T00:00:00", "2012-10-01T00:00:00", "2012-11-01T00:00:00", "2013-01-01T00:00:00", "2013-02-01T00:00:00", "2013-03-01T00:00:00", "2013-04-01T00:00:00", "2013-05-01T00:00:00", "2013-06-01T00:00:00", "2013-07-01T00:00:00", "2013-08-01T00:00:00", "2013-09-01T00:00:00", "2013-10-01T00:00:00", "2013-11-01T00:00:00", "2014-01-01T00:00:00", "2014-02-01T00:00:00", "2014-03-01T00:00:00", "2014-04-01T00:00:00", "2014-05-01T00:00:00", "2014-06-01T00:00:00", "2014-07-01T00:00:00", "2014-08-01T00:00:00", "2014-09-01T00:00:00", "2014-10-01T00:00:00", "2014-11-01T00:00:00", "2015-01-01T00:00:00", "2015-02-01T00:00:00", "2015-03-01T00:00:00", "2015-04-01T00:00:00", "2015-05-01T00:00:00", "2015-06-01T00:00:00", "2015-07-01T00:00:00", "2015-08-01T00:00:00", "2015-09-01T00:00:00", "2015-10-01T00:00:00", "2015-11-01T00:00:00", "2016-01-01T00:00:00", "2016-02-01T00:00:00"], "y": [56549, 55516, 15521, 30368, 52179, 16231, 27460, 29719, 53615, 32662, 10190, 202348, 221220, 154155, 54565, 78891, 58278, 36677, 64447, 50340, 11797, 3796, 184865, 243446, 221085, 89191, 113181, 11295, 68019, 38762, 108884, 74179, 29782, 164865, 254011, 98136, 222921, ...
